# %%
# import packages

import pandas as pd

# %%
# read raw data

df_raw = pd.read_csv('../data/seer_breast_cancer.csv')
df_raw
# Out:
#            Sex                                 COD to site recode  \
# 0       Female                                  Lung and Bronchus
# 1       Female                                  Diseases of Heart
# 2       Female                                  Lung and Bronchus
# 3       Female                                             Breast
# 4       Female  Chronic Obstructive Pulmonary Disease and Alli...
# ...        ...                                                ...
# 656496  Female                                             Breast
# 656497  Female                                             Breast
# 656498  Female                                              Alive
# 656499  Female                                              Alive
# 656500  Female                                              Alive
#
#         Year of diagnosis Behavior code ICD-O-3  \
# 0                    1975             Malignant
# 1                    1988             Malignant
# ...
